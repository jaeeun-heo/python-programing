# %%
print('Hello, Python! :)')
print("My name is Heo Jaeeun")
# Out:
# Hello, Python! :)
# My name is Heo Jaeeun

# %%
# 버전 확인
import sys   #sys; system information
print(sys.version)
# Out:
# 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]

# %%
# 주석 처리
print("HYMOT")   # This will be printed.
#print("hymot")  # This will not be printed.
# Out:
# HYMOT

# %%
# 오류 코드 1
print("error)  # Missing closing quotation mark (SyntaxError)
# Out:
#   Cell In[24], line 2
#     print("error)  # Missing closing quotation mark (SyntaxError)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# 오류 코드 2
frint("error") # Typo in function name (NameError)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # 오류 코드 2
# ----> 2 frint("error") # Typo in function name (NameError)
#
# NameError: name 'frint' is not defined

# %% [markdown]
# **Exercise 1 (Types): Your First Program**

# %%
print("Hello, world!") # Print the traditional hello world
# Out:
# Hello, world!
