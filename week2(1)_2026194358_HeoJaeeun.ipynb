# %%
print('Hello, Python! :)')
print("My name is Heo Jaeeun")
# Out:
# Hello, Python! :)
# My name is Heo Jaeeun

# %%
# 버전 확인
import sys   #sys; system information
print(sys.version)
# Out:
# 3.14.3 (tags/v3.14.3:323c59a, Feb  3 2026, 16:04:56) [MSC v.1944 64 bit (AMD64)]

# %%
# 주석 처리
print("HYMOT")   # This will be printed.
#print("hymot")  # This will not be printed.
# Out:
# HYMOT

# %%
# 오류 코드 1
print("error)  # Missing closing quotation mark (SyntaxError)
# Out:
#   Cell In[24], line 2
#     print("error)  # Missing closing quotation mark (SyntaxError)
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
# 오류 코드 2
frint("error") # Typo in function name (NameError)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 2
#       1 # 오류 코드 2
# ----> 2 frint("error") # Typo in function name (NameError)
#
# NameError: name 'frint' is not defined

# %% [markdown]
# ***

# %% [markdown]
# ### **Exercise 1 (Types): Your First Program**

# %%
print("Hello, world!") # Print the traditional hello world
# Out:
# Hello, world!

# %% [markdown]
# ***

# %%
# Data Type: int (integer,정수)
type(2026)
# Out:
# int

# %%
# Data Type: float (실수)
type(2026.03)
# Out:
# float

# %%
sys.float_info
# Out:
# sys.float_info(max=1.7976931348623157e+308, max_exp=1024, max_10_exp=308, min=2.2250738585072014e-308, min_exp=-1021, min_10_exp=-307, dig=15, mant_dig=53, epsilon=2.220446049250313e-16, radix=2, rounds=1)

# %%
# Data Type: str (string, 문자열)
type("2026년 03월")  # ' 또는 "로 문자 표현
# Out:
# str

# %%
# Convert 실습 1
str(2026.03)  # convert float to string
# Out:
# '2026.03'

# %%
# Convert 실습 2
type(int(2026.03))  # convert float to integer
# Out:
# int

# %% [markdown]
# ***

# %% [markdown]
# ### **Exercise 2 (Types): Get the object type**

# %%
type(12.0)
# Out:
# float

# %% [markdown]
# ***

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)  # 대문자로 표현
# Out:
# bool

# %%
bool(1)  # bool은 T/F 출력
# Out:
# True

# %%
bool(True)
# Out:
# True

# %%
int(True)
# Out:
# 1

# %% [markdown]
# ***

# %% [markdown]
# ### **Exercise 3 (Types): Types**

# %%
type(6/2) # float
# Out:
# float

# %%
type(6//2) # int, as the double slashes stand for integer division
# Out:
# int

# %% [markdown]
# ***

# %% [markdown]
# ### **Exercise 4 (Types): Expression**

# %%
160/60  #float
# Out:
# 2.6666666666666665

# %%
160//60  # int, as the double slashes stand for integer division
# Out:
# 2

# %% [markdown]
# ***

# %% [markdown]
# ### **Exercise 5 (Types): Expression and Variables in Python**

# %%
x = 3 + 2 + 2
x
# Out:
# 7

# %%
y = (3 + 2) * 2
y
# Out:
# 10

# %%
z = x + y
print(z)
# Out:
# 17

# %%
type(z)
# Out:
# int
