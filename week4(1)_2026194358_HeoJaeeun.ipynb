# %% [markdown]
# ## **Conditions in Python**

# %%
a = 194358
# Comprison Operators
print("a:", a)
print("equal: a == 194358 >>", a == 194358)
print("not equal: a != 2026 >>", a != 2026)
print("greater than: a > 19 + 43 + 58 >>", a > 19 + 43 + 58)
print("less than or equal to: a <= 19 * 43 * 58 >>", a <= 19 * 43 * 58)
# Out:
# a: 194358
# equal: a == 194358 >> True
# not equal: a != 2026 >> True
# greater than: a > 19 + 43 + 58 >> True
# less than or equal to: a <= 19 * 43 * 58 >> False

# %%
name = "jaeeun"
name != "Heo"
# Out:
# True

# %%
# Branch
age = 18
print("subway passenger's age:", age)

if age < 8:
    print("fare: free")
elif age < 14:
    print("fare: 500")
elif age < 20:
    print("fare: 1,000")
elif age < 65:
    print("fare: 1,500")
else:
    print("fare: free")

print("Enjoy your trip!")  # 조건문과 관계 없이 출력
# Out:
# subway passenger's age: 18
# fare: 1,000
# Enjoy your trip!

# %%
# Branch & Logical Operators
Q_1 = "W"   # correct
Q_2 = "C"   # wrong

if Q_1 == "C" and Q_2 == "C":
    print("Your score is 10")
elif Q_1 == "C" or Q_2 == "C":
    print("Your score is 5")
else:
    print("Please retake the exam")
# Out:
# Your score is 5

# %% [markdown]
# ***

# %% [markdown]
# ### **Quiz on Conditions**

# %% [markdown]
# #### Write an if statement to determine if an album had a rating greater than 8. Test it using the rating for the album *"Black in Black"* that had a rating of 8.5. If the statement is true print "This album is Amazing!"

# %%
album_rating = 8.5

if album_rating > 8:
    print("This album is Amazing!")
# Out:
# This album is Amazing!

# %% [markdown]
# #### Write an if-else statement that performs the following. If the rating is larger then eight print "this album is amazing". If the rating is less than or equal to 8 print "this album is ok".

# %%
album_rating = 7.5

if album_rating > 8:
    print("this album is amazing")
else:
    print("this album is ok")
# Out:
# this album is ok

# %% [markdown]
# #### Write an if statement to determine if an album came out before 1980 or in the years: 1991 or 1993. If the condition is true print out the year the album came out.

# %%
album_year = 1979

if album_year < 1980 or album_year == 1991 or album_year == 1993:
    print("album year:", album_year)
# Out:
# album year: 1979
